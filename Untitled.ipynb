# %% [markdown]
# # DILI prediction and context aware generation
# Dataset:
# 1. https://www.fda.gov/science-research/liver-toxicity-knowledge-base-ltkb/drug-induced-liver-injury-rank-dilirank-20-dataset.
# 2. https://github.com/bmil-jnu/InterDILI/tree/main
